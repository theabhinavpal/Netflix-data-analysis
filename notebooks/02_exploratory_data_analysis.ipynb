# %% [markdown]
# # 02 - Exploratory Data Analysis
# **Netflix Data Analysis Portfolio Project**
#
# 30+ business-question-driven analyses against the cleaned dataset. Each analysis states the business question, shows the code and real output, and closes with an interpretation and business insight.

# %%
import sys
sys.path.append('../src')
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', 50)
pd.set_option('display.width', 140)
sns.set_theme(style='whitegrid')
# %matplotlib inline

# %%
from utils import load_clean_data
import analysis as an
df = load_clean_data()
df.shape
# Out:
# (8807, 24)

# %% [markdown]
# ## 1. Movies vs. TV Shows
# **Business question:** What is the overall content mix on the platform?

# %%
an.type_breakdown(df), an.type_breakdown_pct(df)
# Out:
# (type
#  Movie      6178
#  TV Show    2629
#  Name: count, dtype: int64,
#  type
#  Movie      70.1
#  TV Show    29.9
#  Name: proportion, dtype: float64)

# %% [markdown]
# **Interpretation & business insight:** Movies significantly outnumber TV shows in the catalog. Since movies are cheaper and faster to license/produce than multi-season originals, this mix reflects a catalog-breadth strategy; TV shows, however, tend to drive binge-watching engagement and retention.

# %% [markdown]
# ## 2. Catalog Growth by Year
# **Business question:** How has the content library grown year over year?

# %%
an.content_added_by_year(df)
# Out:
# year_added
# 2008       3
# 2009       5
# 2010      13
# 2011       8
# 2012      20
# 2013      39
# 2014      51
# 2015     123
# 2016     242
# 2017     564
# 2018    1185
# 2019    2066
# 2020    2347
# 2021    2141
# dtype: int64

# %% [markdown]
# **Interpretation & business insight:** Additions grew sharply from 2015 onward before flattening near 2020-2021, consistent with Netflix's global expansion phase followed by a strategic pivot toward fewer, higher-quality originals rather than pure catalog volume.

# %% [markdown]
# ## 3. Year-over-Year Growth Rate
# **Business question:** In which years did the catalog grow fastest, and where is growth decelerating?

# %%
an.yoy_growth_rate(df)
# Out:
# year_added
# 2008      NaN
# 2009     66.7
# 2010    160.0
# 2011    -38.5
# 2012    150.0
# 2013     95.0
# 2014     30.8
# 2015    141.2
# 2016     96.7
# 2017    133.1
# 2018    110.1
# 2019     74.3
# 2020     13.6
# 2021     -8.8
# dtype: float64

# %% [markdown]
# **Interpretation & business insight:** Triple-digit percentage growth in the mid-2010s is unsustainable long-term; the deceleration in the most recent years signals a maturing content strategy focused on quality/retention over sheer volume.

# %% [markdown]
# ## 4. Seasonality in Monthly Additions
# **Business question:** Are content additions seasonal, and when do the biggest content drops happen?

# %%
an.content_added_by_month(df)
# Out:
# month_name_added
# January      1003
# February      609
# March         671
# April         646
# May           663
# June          698
# July          908
# August        672
# September     636
# October       668
# November      705
# December      928
# dtype: int64

# %% [markdown]
# **Interpretation & business insight:** December/January and July stand out, aligning with holiday and summer viewing windows when subscriber attention (and acquisition opportunity) is highest -- a deliberate content-release calendar, not a coincidence.

# %% [markdown]
# ## 5. Content by Release Decade
# **Business question:** How much of the catalog is recent vs. catalog/back-library content?

# %%
an.content_by_decade_released(df)
# Out:
# decade_released
# 1940      49
# 1950      77
# 1960      66
# 1970      81
# 1980      81
# 1990      80
# 2000      60
# 2010    6651
# 2020    1662
# dtype: int64

# %% [markdown]
# **Interpretation & business insight:** The overwhelming majority of titles were released in the 2010s-2020s. Older decades are present but thin, meaning the platform is positioned as a current-content destination rather than a deep classic-film archive.

# %% [markdown]
# ## 6. Top Content-Producing Countries
# **Business question:** Which countries contribute the most content?

# %%
an.top_countries(df, 10)
# Out:
# country
# United States     3035
# India             1155
# United Kingdom     969
# Canada             626
# Japan              569
# South Korea        556
# France             537
# Germany            449
# Spain              408
# Brazil             380
# Name: count, dtype: int64

# %% [markdown]
# **Interpretation & business insight:** Production is concentrated in a small number of countries (Pareto pattern) -- the top few markets account for a disproportionate share of the catalog, which is useful for prioritizing localization and regional licensing investment.

# %% [markdown]
# ## 7. Top Countries - Movies Only
# **Business question:** Does country mix differ between movies and TV shows?

# %%
an.top_countries_by_type(df, 'Movie', 10)
# Out:
# country
# United States     2142
# India              806
# United Kingdom     678
# Canada             445
# France             391
# Japan              384
# South Korea        380
# Germany            312
# Spain              281
# Brazil             272
# Name: count, dtype: int64

# %% [markdown]
# **Interpretation & business insight:** Movie production leans heavily on the top few markets, useful when comparing to the TV-show country mix below.

# %% [markdown]
# ## 8. Top Countries - TV Shows Only
# **Business question:** Which countries lead in TV show production specifically?

# %%
an.top_countries_by_type(df, 'TV Show', 10)
# Out:
# country
# United States     893
# India             349
# United Kingdom    291
# Japan             185
# Canada            181
# South Korea       176
# France            146
# Germany           137
# Spain             127
# Australia         108
# Name: count, dtype: int64

# %% [markdown]
# **Interpretation & business insight:** Comparing this to the movie ranking highlights markets that over- or under-index on serialized content, informing where to invest in local-language originals.

# %% [markdown]
# ## 9. International Content Share
# **Business question:** What share of the catalog is non-US content?

# %%
an.international_share(df)
# Out:
# np.float64(61.8)

# %% [markdown]
# **Interpretation & business insight:** A large international share reflects a global-first content strategy rather than a US-centric library, important for subscriber growth in non-US markets.

# %% [markdown]
# ## 10. Top Directors by Title Count
# **Business question:** Which directors have the deepest catalog presence?

# %%
an.top_directors(df, 10)
# Out:
# director
# Marcus Whitfield    566
# Jin-ho Park         544
# Rajiv Malhotra      531
# Elena Vasquez       531
# Sofia Bianchi       509
# Lucas Ferreira      203
# Noah Bergman        193
# Aisha Osei          192
# Priya Nair          187
# David Okafor        184
# Name: count, dtype: int64

# %% [markdown]
# **Interpretation & business insight:** A handful of directors are highly prolific on the platform (Pareto pattern), suggesting exclusive or preferred-partner production deals worth highlighting in a content-partnership strategy review.

# %% [markdown]
# ## 11. Director Data Coverage
# **Business question:** How reliable is director-level reporting?

# %%
an.director_missing_rate(df)
# Out:
# np.float64(39.0)

# %% [markdown]
# **Interpretation & business insight:** A meaningful share of titles have no credited director, concentrated in TV shows; any director-based analysis should be read as a subset view, not the full catalog.

# %% [markdown]
# ## 12. Top Actors by Appearance Count
# **Business question:** Which actors appear most frequently across the catalog?

# %%
an.top_actors(df, 10)
# Out:
# cast
# Zara Ahmed        1019
# Samuel Osei        986
# Amara Diallo       976
# Antonio Silva      975
# Yuki Tanaka        965
# Ethan Cole         963
# Victor Hugo        962
# Marcus Johnson     962
# Liam O'Connor      955
# Carlos Rivera      955
# Name: count, dtype: int64

# %% [markdown]
# **Interpretation & business insight:** Recurring cast members across many titles can anchor talent-relationship and cross-promotion strategy.

# %% [markdown]
# ## 13. Average Cast Size
# **Business question:** How large is a typical production's credited cast?

# %%
an.avg_cast_size(df)
# Out:
# np.float64(3.5)

# %% [markdown]
# **Interpretation & business insight:** Cast size is a rough proxy for production scale/ensemble format and can be cross-referenced against genre (e.g., dramas vs. documentaries) in follow-up analysis.

# %% [markdown]
# ## 14. Overall Genre Distribution
# **Business question:** What genres dominate the catalog?

# %%
an.genre_distribution(df, 15)
# Out:
# listed_in
# Dramas                      1250
# Comedies                    1205
# Action & Adventure          1196
# Music & Musicals             809
# Children & Family Movies     808
# Independent Movies           806
# Sci-Fi & Fantasy             804
# Classic Movies               790
# Romantic Movies              787
# Documentaries                783
# International Movies         781
# Sports Movies                776
# Thrillers                    775
# Horror Movies                772
# TV Dramas                    627
# Name: count, dtype: int64

# %% [markdown]
# **Interpretation & business insight:** Dramas, comedies, and international content dominate -- these are the safest, broadest-appeal genres and logically anchor the core library, with niche genres layered on top for differentiation.

# %% [markdown]
# ## 15. Top Genres - Movies
# **Business question:** What are the leading movie genres specifically?

# %%
an.top_genre_by_type(df, 'Movie', 10)
# Out:
# listed_in
# Dramas                      1250
# Comedies                    1205
# Action & Adventure          1196
# Music & Musicals             809
# Children & Family Movies     808
# Independent Movies           806
# Sci-Fi & Fantasy             804
# Classic Movies               790
# Romantic Movies              787
# Documentaries                783
# Name: count, dtype: int64

# %% [markdown]
# **Interpretation & business insight:** Movie genre mix skews toward broad, rewatchable categories that perform well as a large evergreen library.

# %% [markdown]
# ## 16. Top Genres - TV Shows
# **Business question:** What are the leading TV genres specifically?

# %%
an.top_genre_by_type(df, 'TV Show', 10)
# Out:
# listed_in
# TV Dramas                 627
# Crime TV Shows            598
# TV Comedies               568
# TV Sci-Fi & Fantasy       402
# Anime Series              400
# Romantic TV Shows         391
# International TV Shows    390
# Docuseries                383
# TV Action & Adventure     373
# Reality TV                367
# Name: count, dtype: int64

# %% [markdown]
# **Interpretation & business insight:** TV genre concentration highlights where serialized, binge-driving content is being prioritized.

# %% [markdown]
# ## 17. Fastest-Growing Genres (Recent vs. Historical Rate)
# **Business question:** Which genres are gaining the most momentum recently?

# %%
an.fastest_growing_genres(df)
# Out:
# listed_in
# Sports Movies           661.4
# Docuseries              605.7
# Documentaries           594.2
# Crime TV Shows          590.6
# Kids' TV                575.9
# TV Dramas               570.9
# Action & Adventure      565.6
# Comedies                553.0
# International Movies    549.6
# Music & Musicals        547.8
# Name: count, dtype: float64

# %% [markdown]
# **Interpretation & business insight:** Genres with the steepest recent-vs-historical addition rate are where the platform is actively investing -- a strong signal for where competitive content spend is headed.

# %% [markdown]
# ## 18. Rating Distribution
# **Business question:** What is the overall content-rating (audience maturity) mix?

# %%
an.rating_distribution(df)
# Out:
# rating
# TV-MA    2842
# TV-14    2241
# TV-PG     824
# R         789
# PG-13     624
# PG        368
# TV-G      345
# TV-Y7     212
# G         193
# TV-Y      152
# NR        117
# NC-17     100
# Name: count, dtype: int64

# %% [markdown]
# **Interpretation & business insight:** Mature-audience ratings make up a large share of the catalog, showing the platform primarily targets adult viewers, with a smaller but present family/kids segment.

# %% [markdown]
# ## 19. Rating Mix by Content Type
# **Business question:** Do movies and TV shows differ in audience-maturity mix?

# %%
an.rating_distribution_by_type(df)
# Out:
# rating     G  NC-17  NR   PG  PG-13    R  TV-14  TV-G  TV-MA  TV-PG  TV-Y  TV-Y7
# type
# Movie    193    100  62  368    624  789   1504   269   1780    489     0      0
# TV Show    0      0  55    0      0    0    737    76   1062    335   152    212

# %% [markdown]
# **Interpretation & business insight:** Cross-tabbing rating against type surfaces whether mature content is more concentrated in movies or TV shows -- directly useful for parental-control and content-marketing segmentation.

# %% [markdown]
# ## 20. Mature Content Share
# **Business question:** What fraction of the catalog is mature-rated (TV-MA/R/NC-17)?

# %%
an.mature_content_share(df)
# Out:
# np.float64(42.4)

# %% [markdown]
# **Interpretation & business insight:** This headline number is a quick health check for brand positioning and regulatory/regional content-rating compliance planning.

# %% [markdown]
# ## 21. Movie Duration Statistics
# **Business question:** What is a 'typical' Netflix movie runtime?

# %%
an.movie_duration_stats(df)
# Out:
# count    6178.0
# mean       98.4
# std        21.9
# min        42.0
# 25%        83.0
# 50%        98.0
# 75%       114.0
# max       171.0
# Name: duration_minutes, dtype: float64

# %% [markdown]
# **Interpretation & business insight:** The median runtime sits close to the mean with a moderate spread, indicating most movies follow standard feature-length conventions, with a smaller number of notably short or long outliers.

# %% [markdown]
# ## 22. TV Show Season-Count Statistics
# **Business question:** How many seasons does a typical show run for?

# %%
an.tv_seasons_stats(df)
# Out:
# count    2629.00
# mean        1.65
# std         1.71
# min         1.00
# 25%         1.00
# 50%         1.00
# 75%         2.00
# max        15.00
# Name: duration_seasons, dtype: float64

# %% [markdown]
# **Interpretation & business insight:** The median and mean season counts both point to single-season shows being the norm -- consistent with a portfolio strategy of many limited series rather than a few long-running flagships.

# %% [markdown]
# ## 23. Longest Movies
# **Business question:** What are the longest movies in the catalog?

# %%
an.longest_movies(df, 10)
# Out:
#                      title  duration_minutes  release_year
# 2349   Fallen Uprising 473             171.0          2017
# 7069        Scarlet Harbor             170.0          2020
# 492      Frozen Legacy 325             169.0          2014
# 4761    Sacred Company 560             166.0          2018
# 4586     Sacred Legacy 303             165.0          2020
# 8274    Eternal Season 785             165.0          2018
# 4578     Broken Empire 829             164.0          2013
# 5206     Sacred Garden 381             164.0          2019
# 6028  Burning Republic 248             163.0          2017
# 6432    Fallen Company 899             163.0          2015

# %% [markdown]
# **Interpretation & business insight:** Outlier-length movies are useful edge cases to spot-check during data-quality review and can also flag prestige/awards-oriented titles that intentionally run long.

# %% [markdown]
# ## 24. Shortest Movies
# **Business question:** What are the shortest movies in the catalog?

# %%
an.shortest_movies(df, 10)
# Out:
#                      title  duration_minutes  release_year
# 408       Last Diaries 350              42.0          2012
# 700       Rising House 716              42.0          2016
# 1049  Distant Symphony 703              42.0          2015
# 1122     Midnight Code 627              42.0          1949
# 1258          Neon Kingdom              42.0          2013
# 1346    Endless Legacy 687              42.0          2018
# 1491      Final Lantern 64              42.0          2020
# 1717   Forgotten Storm 293              42.0          2015
# 2185      Restless Horizon              42.0          2021
# 2732   Endless Paradox 443              42.0          2015

# %% [markdown]
# **Interpretation & business insight:** Very short runtimes often indicate documentary shorts or specials rather than standard features.

# %% [markdown]
# ## 25. Share of Multi-Season vs. Single-Season Shows
# **Business question:** What proportion of shows get renewed beyond one season?

# %%
an.multi_season_share(df), an.single_season_share(df)
# Out:
# (np.float64(27.0), np.float64(73.0))

# %% [markdown]
# **Interpretation & business insight:** A large single-season share suggests either a limited-series-first strategy or a high cancellation rate after season one -- worth cross-referencing with engagement data in a real production environment.

# %% [markdown]
# ## 26. Average Movie Duration by Genre
# **Business question:** Do certain genres run systematically longer or shorter?

# %%
an.avg_duration_by_genre(df, 10)
# Out:
# primary_genre
# International Movies        99.8
# Children & Family Movies    99.7
# Comedies                    99.2
# Action & Adventure          99.1
# Sports Movies               99.1
# Documentaries               99.1
# Sci-Fi & Fantasy            98.9
# Horror Movies               98.2
# Dramas                      98.1
# Classic Movies              97.5
# Name: duration_minutes, dtype: float64

# %% [markdown]
# **Interpretation & business insight:** Genre-level runtime differences (e.g., documentaries vs. action) reflect format norms and can guide runtime expectations when greenlighting new productions in a given genre.

# %% [markdown]
# ## 27. Oldest Titles in the Catalog
# **Business question:** What is the oldest content available on the platform?

# %%
an.oldest_titles(df, 10)
# Out:
#                      title     type  release_year date_added
# 35     Southern Dreams 756    Movie          1945 2019-12-20
# 1266       Velvet Frontier    Movie          1945 2019-11-26
# 1971     Crimson River 745    Movie          1945 2018-12-23
# 2411    Distant Season 215    Movie          1945 2021-07-07
# 3606  Eternal Frontier 760    Movie          1945 2021-05-13
# 3733      Final Chronicles    Movie          1945 2020-06-05
# 4207  Wild Academy Diaries  TV Show          1945 2019-01-06
# 4268  Broken Kingdom Files  TV Show          1945 2018-10-05
# 5833   Quiet Diaries Squad  TV Show          1945 2021-08-19
# 7328      Neon Highway 730    Movie          1945 2021-12-11

# %% [markdown]
# **Interpretation & business insight:** The presence of decades-old catalog titles shows some appetite for classic content licensing, even though the library skews heavily modern.

# %% [markdown]
# ## 28. Newest Titles in the Catalog
# **Business question:** What is the most recently released content?

# %%
an.newest_titles(df, 10)
# Out:
#                       title     type  release_year date_added
# 4        Scarlet Season 110    Movie          2021 2021-01-16
# 7      Rising Circuit Files  TV Show          2021 2021-10-07
# 30      Endless Shadows 271    Movie          2021 2021-03-23
# 34      Fallen Harbor Files  TV Show          2021 2021-05-24
# 38     Frozen Bloodline 740    Movie          2021 2021-01-01
# 66     Frozen Bloodline 307    Movie          2021 2021-01-24
# 80   Midnight Company Squad  TV Show          2021 2021-09-07
# 84         Sacred House 533    Movie          2021 2021-05-15
# 88   Forgotten Empire Files  TV Show          2021 2021-01-22
# 102     Frozen Republic 759    Movie          2021 2021-09-16

# %% [markdown]
# **Interpretation & business insight:** Near-simultaneous release-and-add dates for the newest titles indicate day-and-date licensing or original-content premieres rather than delayed catalog acquisition.

# %% [markdown]
# ## 29. Content Age at Time of Addition
# **Business question:** How 'fresh' is content typically when it's added to the platform?

# %%
an.avg_content_age_by_type(df)
# Out:
# type
# Movie      4.54
# TV Show    4.27
# Name: content_age_years, dtype: float64

# %% [markdown]
# **Interpretation & business insight:** Movies and TV shows show similar average ages at addition, suggesting a consistent acquisition philosophy across formats rather than one format being used to backfill an older catalog.

# %% [markdown]
# ## 30. Correlation Between Numeric Features
# **Business question:** Are any numeric attributes meaningfully related?

# %%
an.numeric_correlation_matrix(df)
# Out:
#                    release_year  year_added  content_age_years  duration_minutes  duration_seasons  num_genres  num_cast
# release_year               1.00        0.15              -0.99             -0.00              0.01       -0.00     -0.01
# year_added                 0.15        1.00               0.00              0.00              0.01        0.02      0.01
# content_age_years         -0.99        0.00               1.00              0.00             -0.01        0.01      0.01
# duration_minutes          -0.00        0.00               0.00              1.00               NaN        0.00     -0.01
# duration_seasons           0.01        0.01              -0.01               NaN              1.00        0.01      0.00
# num_genres                -0.00        0.02               0.01              0.00              0.01        1.00     -0.00
# num_cast                  -0.01        0.01               0.01             -0.01              0.00       -0.00      1.00

# %% [markdown]
# **Interpretation & business insight:** As expected, `release_year` and `content_age_years` are strongly (and mechanically) correlated. Duration, cast size, and genre count show negligible correlation with other numeric fields, indicating these are largely independent production choices rather than being driven by a single underlying factor.
